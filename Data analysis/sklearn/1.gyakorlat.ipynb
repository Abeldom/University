# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
array = np.arange(6,30,3)

# %%
array[0:3]
# Out:
# array([ 6,  9, 12])

# %%
numbers = pd.Series(array)
numbers
# Out:
# 0     6
# 1     9
# 2    12
# 3    15
# 4    18
# 5    21
# 6    24
# 7    27
# dtype: int64

# %%
numbers = pd.Series(np.arange(5), index=['a','b','c','d','e'])
numbers['e']
# Out:
# 4

# %%
numbers.iloc[-3:]
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
numbers.min()
# Out:
# 0

# %%
numbers.head()
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
numbers_sq=numbers.apply(lambda x:x*x)
numbers_sq
# Out:
# a     0
# b     1
# c     4
# d     9
# e    16
# dtype: int64

# %%
numbers_df=pd.DataFrame({'szamok':numbers,'negyzetek':numbers_sq})
numbers_df
# Out:
#    szamok  negyzetek
# a       0          0
# b       1          1
# c       2          4
# d       3          9
# e       4         16

# %%
numbers_df.describe()
# Out:
#          szamok  negyzetek
# count  5.000000   5.000000
# mean   2.000000   6.000000
# std    1.581139   6.595453
# min    0.000000   0.000000
# 25%    1.000000   1.000000
# 50%    2.000000   4.000000
# 75%    3.000000   9.000000
# max    4.000000  16.000000

# %%
numbers_df.shape
# Out:
# (5, 2)

# %%
numbers_df.columns
# Out:
# Index(['szamok', 'negyzetek'], dtype='object')

# %%
numbers_df['kobok']=numbers_df.apply(lambda x:x['szamok']*x['negyzetek'],axis=1) #
numbers_df
# Out:
#    szamok  negyzetek  kobok
# a       0          0      0
# b       1          1      1
# c       2          4      8
# d       3          9     27
# e       4         16     64

# %%
numbers_df.apply(lambda x:x.sum(),axis=0)
# Out:
# szamok        10
# negyzetek     30
# kobok        100
# dtype: int64

# %%
idx = numbers_df['kobok']%2==0
idx
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# Name: kobok, dtype: bool

# %%
numbers_df[idx]
# Out:
#    szamok  negyzetek  kobok
# a       0          0      0
# c       2          4      8
# e       4         16     64

# %%
numbers_df.query('kobok % 2 == 0')
# Out:
#    szamok  negyzetek  kobok
# a       0          0      0
# c       2          4      8
# e       4         16     64

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python/Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.shape
# Out:
# (800, 13)

# %%
df.drop('Name',axis=1,inplace=True)
df
# Out:
#        #   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1    Grass  Poison    318  45      49       49       65       65
# 1      2    Grass  Poison    405  60      62       63       80       80
# 2      3    Grass  Poison    525  80      82       83      100      100
# 3      3    Grass  Poison    625  80     100      123      122      120
# 4      4     Fire     NaN    309  39      52       43       60       50
# ..   ...      ...     ...    ...  ..     ...      ...      ...      ...
# 795  719     Rock   Fairy    600  50     100      150      100      150
# 796  719     Rock   Fairy    700  50     160      110      160      110
# 797  720  Psychic   Ghost    600  80     110       60      150      130
# 798  720  Psychic    Dark    680  80     160       60      170      130
# 799  721     Fire   Water    600  80     110      120      130       90
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 1       60           1      False
# 2       80           1      False
# 3       80           1      False
# 4       65           1      False
# ..     ...         ...        ...
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [800 rows x 12 columns]

# %%
df.query('Generation == 2 & Defense >= 2*Attack')
# Out:
#        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 189  175  Fairy     NaN    245  35      20       65       40       65     20
# 190  176  Fairy  Flying    405  55      40       85       80      105     40
# 198  183  Water   Fairy    250  70      20       50       20       50     40
# 223  208  Steel  Ground    510  75      85      200       55       65     30
# 230  213    Bug    Rock    505  20      10      230       10      230      5
# 237  219   Fire    Rock    410  50      50      120       80       80     30
#
#      Generation  Legendary
# 189           2      False
# 190           2      False
# 198           2      False
# 223           2      False
# 230           2      False
# 237           2      False

# %%
df[(df['Generation']==2) & (df['Defense']>= 2*df['Attack'])]
# Out:
#        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 189  175  Fairy     NaN    245  35      20       65       40       65     20
# 190  176  Fairy  Flying    405  55      40       85       80      105     40
# 198  183  Water   Fairy    250  70      20       50       20       50     40
# 223  208  Steel  Ground    510  75      85      200       55       65     30
# 230  213    Bug    Rock    505  20      10      230       10      230      5
# 237  219   Fire    Rock    410  50      50      120       80       80     30
#
#      Generation  Legendary
# 189           2      False
# 190           2      False
# 198           2      False
# 223           2      False
# 230           2      False
# 237           2      False

# %%
idx1= df['Generation']==2
idx2 = df['Defense']>= 2*df['Attack']
df[idx1 & idx2]
# Out:
#        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 189  175  Fairy     NaN    245  35      20       65       40       65     20
# 190  176  Fairy  Flying    405  55      40       85       80      105     40
# 198  183  Water   Fairy    250  70      20       50       20       50     40
# 223  208  Steel  Ground    510  75      85      200       55       65     30
# 230  213    Bug    Rock    505  20      10      230       10      230      5
# 237  219   Fire    Rock    410  50      50      120       80       80     30
#
#      Generation  Legendary
# 189           2      False
# 190           2      False
# 198           2      False
# 223           2      False
# 230           2      False
# 237           2      False

# %%
df.query('Speed >= Speed.mean()')
# Out:
#        #   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 2      3    Grass  Poison    525   80      82       83      100      100
# 3      3    Grass  Poison    625   80     100      123      122      120
# 5      5     Fire     NaN    405   58      64       58       80       65
# 6      6     Fire  Flying    534   78      84       78      109       85
# 7      6     Fire  Dragon    634   78     130      111      130       85
# ..   ...      ...     ...    ...  ...     ...      ...      ...      ...
# 794  718   Dragon  Ground    600  108     100      121       81       95
# 796  719     Rock   Fairy    700   50     160      110      160      110
# 797  720  Psychic   Ghost    600   80     110       60      150      130
# 798  720  Psychic    Dark    680   80     160       60      170      130
# 799  721     Fire   Water    600   80     110      120      130       90
#
#      Speed  Generation  Legendary
# 2       80           1      False
# 3       80           1      False
# 5       80           1      False
# 6      100           1      False
# 7      100           1      False
# ..     ...         ...        ...
# 794     95           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [376 rows x 12 columns]

# %%
df[df['Speed']>df['Speed'].mean()]
# Out:
#        #   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 2      3    Grass  Poison    525   80      82       83      100      100
# 3      3    Grass  Poison    625   80     100      123      122      120
# 5      5     Fire     NaN    405   58      64       58       80       65
# 6      6     Fire  Flying    534   78      84       78      109       85
# 7      6     Fire  Dragon    634   78     130      111      130       85
# ..   ...      ...     ...    ...  ...     ...      ...      ...      ...
# 794  718   Dragon  Ground    600  108     100      121       81       95
# 796  719     Rock   Fairy    700   50     160      110      160      110
# 797  720  Psychic   Ghost    600   80     110       60      150      130
# 798  720  Psychic    Dark    680   80     160       60      170      130
# 799  721     Fire   Water    600   80     110      120      130       90
#
#      Speed  Generation  Legendary
# 2       80           1      False
# 3       80           1      False
# 5       80           1      False
# 6      100           1      False
# 7      100           1      False
# ..     ...         ...        ...
# 794     95           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [376 rows x 12 columns]

# %%
df.groupby(by='Generation').mean()['Attack']
# Out:
# <ipython-input-45-e206e585c683>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by='Generation').mean()['Attack']
# Generation
# 1    76.638554
# 2    72.028302
# 3    81.625000
# 4    82.867769
# 5    82.066667
# 6    75.804878
# Name: Attack, dtype: float64

# %%
df.plot.scatter(x='Speed',y='Defense')
# Out:
# <Axes: xlabel='Speed', ylabel='Defense'>

# %%
stats_by_generation = df.groupby('Generation').mean()[['HP', 'Attack', 'Defense', 'Speed']]
stats_by_generation.plot.line()
# Out:
# <ipython-input-52-dd1ebf3f52d9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   stats_by_generation = df.groupby('Generation').mean()[['HP', 'Attack', 'Defense', 'Speed']]
# <Axes: xlabel='Generation'>

# %%
df['Attack'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Speed'],df['Defense'])

# %%
df.plot.hexbin(x='Speed', y='Defense', gridsize=20)
# Out:
# <Axes: xlabel='Speed', ylabel='Defense'>

# %%
# Könyvtár ábrák készítéséhez

from matplotlib import pyplot as plt

# %%
# Az előző ábra átalakítva
# figsize - az ábra mérete
# s - pontok mérete
# c - pontok színe
# marker - pontok alakja
# alpha - átlátszóság

plt.figure(figsize=(12,6))
plt.scatter(df['Speed'], df['Defense'], s=25, c='red', marker='x', alpha=0.5)
plt.xlabel("Speed")
plt.ylabel("Defense")
plt.show()

# %%
stats_by_gen_leg = df.groupby(by=['Generation', 'Legendary']).mean()[['HP', 'Attack']]
stats_by_gen_leg.plot.bar()
# Out:
# <ipython-input-58-699b3ad9cd9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   stats_by_gen_leg = df.groupby(by=['Generation', 'Legendary']).mean()[['HP', 'Attack']]
# <Axes: xlabel='Generation,Legendary'>

# %%
stats_by_gen_leg.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='Generation,Legendary'>

# %%
sel = df[['HP','Attack','Defense', 'Speed']]
clist = [x for x in sel.columns if x!='HP']
colors = ['red', 'blue', 'green']
fig, ax = plt.subplots(len(clist), 1, figsize=(10,10))
for i in range(len(clist)):
    cn = clist[i]
    ax[i].scatter(sel['HP'],sel[cn], alpha=0.5, label=cn, c=colors[i])
    ax[i].set_xlabel('HP')
    ax[i].set_ylabel(cn)
    ax[i].set_ylim(0,200)
    ax[i].legend()
plt.show()

# %%
# Plot cheat sheet

# https://www.kaggle.com/code/themlphdstudent/cheatsheet-matplotlib-charts/notebook

# Plotolás feladatok

# 1. feladat
# Add meg, hogy milyen típusú pokémonok rendelkeznek átlagosan a legnagyobb támadó értékkel
# Ábrázolt az eredményt barchart segítségével

type_group = df.groupby(by='Type 1').mean()[['Attack']]
type_group.plot.bar()
# Out:
# <ipython-input-61-c4f0b63e2120>:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   type_group = df.groupby(by='Type 1').mean()[['Attack']]
# <Axes: xlabel='Type 1'>

# %%
# 2. feladat
# Add meg, hogy az egyes generációkhoz hány pokémon tartozik.
# Jelenítsd meg az eredményt tetszőleges típusú ábrával.

generation_group = df.groupby(by='Generation').size()
generation_group.plot.line(marker='s')
# Out:
# <Axes: xlabel='Generation'>
